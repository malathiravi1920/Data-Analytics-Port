# %% [markdown]
# Scenario 1 – Missing File

# %%
try:
    o=open(r"C:\Users\ELCOT\Data Analytics Port\PYTHON\Assignment4\Feedback.csv1",'r')
except FileNotFoundError:
    print("File not found")
# Out:
# File not found

# %% [markdown]
# Scenario 2 – Invalid Rating

# %%
try:
    num=int(input("Enter the number:"))
    print(num)
except ValueError:
    print("Invalid rating found")
# Out:
# Invalid rating found

# %% [markdown]
# Scenario 3 – Empty Rating

# %% [markdown]
# Exception using Final

# %%
try:
    num=int(input("Enter the number:"))
    print(num)
except ValueError:
    print("Invalid rating found")
finally:
    print("process completed")

# %% [markdown]
# Real-World Data Cleaning

# %%
input=[4, 5.0, "Excellent", -2, 3]
total_customers = len(input)
valid_count = 0
invalid_count = 0
valid_sum = 0


for item in input:

    if item is None or str(item).strip() == "":
        continue

    else:
        try:
            number=float(item)
            if number > 1 &number <5:
                valid_count+=1
                valid+=number
                #valid_ratings_list.append(number) 
            else:
                invalid_count+=1
                
                print("Negative values or values less than 1 are ignored.")
            elif number > 5:
                print("Values greater than 5 are ignored.")
            else:
                print(f"Valid rating accepted: {number}")
            
            Total_Valid_Ratings+=1

            Average_Ratings(number)



            
    except ValueError:
        print("Text values are ignored. Only write the number.")

# %% [markdown]
# Total Customers
# Total Valid Ratings
# Total Invalid Ratings
# Average Rating
# Highest Rating
# Lowest Rating
