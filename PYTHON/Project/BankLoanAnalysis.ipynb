# %% [markdown]
#  BANK LOAN ANALYSIS  REPORT

# %% [markdown]
#  IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px

# %%
df=pd.read_excel(r"C:\Users\ELCOT\Downloads\financial_loan.xlsx")
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %% [markdown]
# #MetaData of data

# %%
print("No of Rows",df.shape[0])
# Out:
# No of Rows 38576

# %%
print("No of columns:",df.shape[1])
# Out:
# No of columns: 24

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  str
#  2   application_type       38576 non-null  str
#  3   emp_length             38576 non-null  str
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  str
#  6   home_ownership         38576 non-null  str
#  7   issue_date             38576 non-null  datetime64[us]
#  8   last_credit_pull_date  38576 non-null  datetime64[us]
#  9   last_payment_date      38576 non-null  datetime64[us]
#  10  loan_status            38576 non-null  str
#  11  next_payment_date      38576 non-null  datetime64[us]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  str
# ...

# %% [markdown]
#  Data Types

# %%
df.dtypes
# Out:
# id                                int64
# address_state                       str
# application_type                    str
# emp_length                          str
# emp_title                        object
# grade                               str
# home_ownership                      str
# issue_date               datetime64[us]
# last_credit_pull_date    datetime64[us]
# last_payment_date        datetime64[us]
# loan_status                         str
# next_payment_date        datetime64[us]
# member_id                         int64
# purpose                             str
# sub_grade                           str
# term                                str
# verification_status                 str
# annual_income                   float64
# dti                             float64
# installment                     float64
# int_rate                        float64
# loan_amount                       int64
# total_acc                         int64
# ...

# %%
df.describe()
# Out:
#                  id                  issue_date       last_credit_pull_date  \
# count  3.857600e+04                       38576                       38576
# mean   6.810371e+05  2021-07-16 02:31:35.562007  2021-06-08 13:36:34.193280
# min    5.473400e+04         2021-01-01 00:00:00         2021-01-08 00:00:00
# 25%    5.135170e+05         2021-04-11 00:00:00         2021-04-15 00:00:00
# 50%    6.627280e+05         2021-07-11 00:00:00         2021-05-16 00:00:00
# 75%    8.365060e+05         2021-10-11 00:00:00         2021-08-13 00:00:00
# max    1.077501e+06         2021-12-12 00:00:00         2022-01-20 00:00:00
# std    2.113246e+05                         NaN                         NaN
#
#                 last_payment_date           next_payment_date     member_id  \
# count                       38576                       38576  3.857600e+04
# mean   2021-06-26 09:52:08.909166  2021-07-26 20:42:20.605557  8.476515e+05
# ...

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %% [markdown]
#   Toatal Loan Application

# %%
total_loan_application=df['id'].count()
print("Total Loan Application:",total_loan_application)
# Out:
# Total Loan Application: 38576

# %% [markdown]
#  MTD Total Loan Application

# %%
latest_date=df['issue_date'].max()
print(latest_date)
latest_year=latest_date.year
print(latest_year)
latest_month=latest_date.month
print(latest_month)

mtd_data=df[(df['issue_date'].dt.year == latest_year) & (df['issue_date'].dt.month == latest_month)]
print(mtd_data)

#filtering
mtd_loan_application=mtd_data['id'].count()
print(f"MTD Loan Application:(for {latest_date.strftime("%B %Y")}):{mtd_loan_application}")
# Out:
# 2021-12-12 00:00:00
# 2021
# 12
#             id address_state application_type emp_length  \
# 13     1020855            CA       INDIVIDUAL    5 years
# 15     1060995            RI       INDIVIDUAL   < 1 year
# 16     1046507            TX       INDIVIDUAL     1 year
# 18     1059497            FL       INDIVIDUAL  10+ years
# 42      472634            FL       INDIVIDUAL     1 year
# ...        ...           ...              ...        ...
# 38496  1026558            CA       INDIVIDUAL    4 years
# 38516   633392            CT       INDIVIDUAL  10+ years
# 38531  1052169            NY       INDIVIDUAL     1 year
# 38535   624384            MA       INDIVIDUAL    4 years
# 38546   634116            FL       INDIVIDUAL    6 years
#
#                         emp_title grade home_ownership issue_date  \
# 13             henkel corporation     B           RENT 2021-12-11
# 15                        HSA-UWC     B           RENT 2021-12-11
# ...

# %% [markdown]
# # Total Found Data

# %%
total_found_data=df['loan_amount'].sum()
print(total_found_data)
total_found_millions=total_found_data/1000000
print(f"Total Funded Amount: ${total_found_millions:.2f}M")
# Out:
# 435757075
# Total Funded Amount: $435.76M

# %% [markdown]
# MTD Total Found Data

# %%
latest_date=df['issue_date'].max()
print(latest_date)
latest_year=latest_date.year
print(latest_year)
latest_month=latest_date.month
print(latest_month)

mtd_data=df[(df['issue_date'].dt.year == latest_year) & (df['issue_date'].dt.month == latest_month)]
print(mtd_data)

mtd_total_fund_data=mtd_data['loan_amount'].sum()
mtd_total_funded_amount_millions=mtd_total_fund_data/100000
print(f"MTD Total Found Amount: {mtd_total_funded_amount_millions:.2f}M")
# Out:
# 2021-12-12 00:00:00
# 2021
# 12
#             id address_state application_type emp_length  \
# 13     1020855            CA       INDIVIDUAL    5 years
# 15     1060995            RI       INDIVIDUAL   < 1 year
# 16     1046507            TX       INDIVIDUAL     1 year
# 18     1059497            FL       INDIVIDUAL  10+ years
# 42      472634            FL       INDIVIDUAL     1 year
# ...        ...           ...              ...        ...
# 38496  1026558            CA       INDIVIDUAL    4 years
# 38516   633392            CT       INDIVIDUAL  10+ years
# 38531  1052169            NY       INDIVIDUAL     1 year
# 38535   624384            MA       INDIVIDUAL    4 years
# 38546   634116            FL       INDIVIDUAL    6 years
#
#                         emp_title grade home_ownership issue_date  \
# 13             henkel corporation     B           RENT 2021-12-11
# 15                        HSA-UWC     B           RENT 2021-12-11
# ...

# %% [markdown]
# Total Amount Received

# %%
total_amount_received=df['total_payment'].sum()
print(total_amount_received)
total_amount_received_millions=total_amount_received/1000000
print(f"Total Amount Received: ${total_amount_received_millions:.2f}M")
# Out:
# 473070933
# Total Amount Received: $473.07M

# %% [markdown]
# MTD Total Amount Received

# %%
latest_date=df['issue_date'].max()
print(latest_date)
latest_year=latest_date.year
print(latest_year)
latest_month=latest_date.month
print(latest_month)

mtd_data=df[(df['issue_date'].dt.year == latest_year) & (df['issue_date'].dt.month == latest_month)]
print(mtd_data)

mtd_total_received_data=mtd_data['total_payment'].sum()
mtd_total_amount_received_millions=mtd_total_received_data/100000
print(f"MTD Total Found Amount: {mtd_total_amount_received_millions:.2f}M")
# Out:
# 2021-12-12 00:00:00
# 2021
# 12
#             id address_state application_type emp_length  \
# 13     1020855            CA       INDIVIDUAL    5 years
# 15     1060995            RI       INDIVIDUAL   < 1 year
# 16     1046507            TX       INDIVIDUAL     1 year
# 18     1059497            FL       INDIVIDUAL  10+ years
# 42      472634            FL       INDIVIDUAL     1 year
# ...        ...           ...              ...        ...
# 38496  1026558            CA       INDIVIDUAL    4 years
# 38516   633392            CT       INDIVIDUAL  10+ years
# 38531  1052169            NY       INDIVIDUAL     1 year
# 38535   624384            MA       INDIVIDUAL    4 years
# 38546   634116            FL       INDIVIDUAL    6 years
#
#                         emp_title grade home_ownership issue_date  \
# 13             henkel corporation     B           RENT 2021-12-11
# 15                        HSA-UWC     B           RENT 2021-12-11
# ...

# %% [markdown]
# Average Interest Rate

# %%
average_interest_rate=df['int_rate'].mean()*100
print(f"Average Int Rate:{average_interest_rate:.2f}M")
# Out:
# Average Int Rate:12.05M

# %% [markdown]
# Average Debt-to-Income Ratio(DTI)

# %%
average_DTI_rate=df['dti'].mean()*100
print(f"Average DTI Rate:{average_DTI_rate:.2f}M")
# Out:
# Average DTI Rate:13.33M

# %% [markdown]
# Good Loan

# %%
good_loan=df[df['loan_status'].isin(["Fully Paid","Current"])]

total_loan_application=df['id'].count()

good_loan_application=good_loan['id'].count()
good_loan_funded_amounts=good_loan['loan_amount'].sum()
good_loan_received=good_loan['total_payment'].sum()

good_loan_found_amounts_millions=good_loan_funded_amounts/1000000
good_loan_received_millions=good_loan_received/1000000

good_loan_percentage=(good_loan_application/total_loan_application)*100

print(f"Good Loan Application:",good_loan_application)
print(f"Good Loan Funded Amount:{good_loan_found_amounts_millions:.2f}M")
print(f"Good Loan Received Amount:{good_loan_received_millions:.2f}M")
print(f"Good Loan Percentage:{good_loan_percentage:.2f}%")
# Out:
# Good Loan Application: 33243
# Good Loan Funded Amount:370.22M
# Good Loan Received Amount:435.79M
# Good Loan Percentage:86.18%

# %% [markdown]
# Bad Loan

# %%
bad_loan=df[df['loan_status'].isin(["Charged Off"])]

total_loan_application=df['id'].count()

bad_loan_application=bad_loan['id'].count()
bad_loan_funded_amounts=bad_loan['loan_amount'].sum()
bad_loan_received=bad_loan['total_payment'].sum()

bad_loan_found_amounts_millions=bad_loan_funded_amounts/1000000
bad_loan_received_millions=bad_loan_received/1000000

bad_loan_percentage=(bad_loan_application/total_loan_application)*100

print(f"Bad Loan Application:",bad_loan_application)
print(f"Bad Loan Funded Amount:{bad_loan_found_amounts_millions:.2f}M")
print(f"Bad Loan Received Amount:{bad_loan_received_millions:.2f}M")
print(f"Bad Loan Percentage:{bad_loan_percentage:.2f}%")
# Out:
# Bad Loan Application: 5333
# Bad Loan Funded Amount:65.53M
# Bad Loan Received Amount:37.28M
# Bad Loan Percentage:13.82%
